# %% [markdown]
# # Linguistic Features Pipeline
#
# This notebook extracts linguistic features for the gaze-guided text generation study:
# - **Word frequency**: SUBTLEX-US Zipf scores (lemma-first, then surface)
# - **Word length**: Alphabetic character count
# - **Dependency distance**: Linear distance to syntactic head (Gibson 2000 locality theory)
# - **Syntactic tree depth**: Distance from token to root
# - **Integration cost**: Locality-based processing difficulty metric
#
# Features are aligned to AOI tokens and merged with TRT data for mixed-effects modeling.

# %%
# Install dependencies with version pins for reproducibility
# %pip install -q "spacy==3.7.4" "polars==1.6.0" "pyarrow==15.0.2"

# Download spaCy model if not present
import subprocess
import sys
try:
    import en_core_web_sm
except ImportError:
    print("Downloading spaCy English model...")
    subprocess.check_call([sys.executable, "-m", "spacy", "download", "en_core_web_sm"])
# Out:
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Python312\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Mert Yeşilyurt\AppData\Local\Temp\pip-uninstall-k8dy9wfg'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Mert Yeşilyurt\AppData\Local\Temp\pip-uninstall-ravl856u'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Python312\Lib\site-packages\~.mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Python312\Lib\site-packages\numpy\~.t'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Python312\Lib\site-packages\numpy\~.nalg'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Python312\Lib\site-packages\numpy\~.ndom'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Python312\Lib\site-packages\~yarrow'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution ~ (c:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (c:\Python312\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymovements 0.23.0 requires polars<1.32,>=1.31.0, but you have polars 1.6.0 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
# C:\Python312\Lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.8.0) was trained with spaCy v3.8.0 and may not be 100% compatible with the current version (3.7.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
from pathlib import Path
import json
import re
import polars as pl
import spacy

# Paths
BASE = Path("data-clean")
RAW = BASE / "raw"
TEXTS_DIR = RAW / "texts"
STIMULI_DIR = RAW / "stimuli"
PROC = BASE / "processed"
RESOURCES = BASE / "resources"

# Ensure output directory exists
PROC.mkdir(parents=True, exist_ok=True)

# File paths
TRT_PARQUET = PROC / "trt_by_word.parquet"
TRT_CSV = PROC / "trt_by_word.csv"
SUBTLEX_PATH = RESOURCES / "SUBTLEX-US.csv"

print(f"Base directory: {BASE.absolute()}")
print(f"SUBTLEX exists: {SUBTLEX_PATH.exists()}")
print(f"TRT data exists: {TRT_PARQUET.exists() or TRT_CSV.exists()}")
# Out:
# Base directory: c:\a\project\data-clean
# SUBTLEX exists: True
# TRT data exists: True

# %%
# Helper functions
def is_practice(name: str) -> bool:
    return "practice" in name.lower()

def extract_condition(name: str) -> str:
    lname = name.lower()
    if "neg" in lname: return "neg"
    if "pos" in lname: return "pos"  
    if "zero" in lname: return "zero"
    return "unknown"

# Text normalization for alignment
_punct_re = re.compile(r"[^\w']+", flags=re.UNICODE)

def normalize_token(s: str) -> str:
    """Normalize token for alignment: lowercase, keep apostrophes, remove other punct."""
    return _punct_re.sub("", s.lower())

def align_aoi_to_spacy(aoi_tokens: list[str], doc_tokens: list[str]) -> list[int | None]:
    """
    Greedy left-to-right alignment by normalized surface forms.
    Returns alignment indices for AOI tokens to spaCy doc tokens.
    """
    mapping: list[int | None] = [None] * len(aoi_tokens)
    j = 0
    
    for i, aoi_token in enumerate(aoi_tokens):
        norm_aoi = normalize_token(aoi_token)
        if not norm_aoi:
            continue
            
        # Find matching spaCy token
        while j < len(doc_tokens):
            norm_doc = normalize_token(doc_tokens[j])
            if not norm_doc:
                j += 1
                continue
                
            if norm_doc == norm_aoi:
                mapping[i] = j
                j += 1
                break
            else:
                j += 1
                
    return mapping

# %%
# Load TRT data to get stimulus list (excludes practice)
if TRT_PARQUET.exists():
    trt = pl.read_parquet(TRT_PARQUET)
else:
    trt = pl.read_csv(TRT_CSV)

# Filter out practice stimuli
trt = trt.filter(~pl.col("stimulus").str.contains("practice"))
stimuli_to_process = trt["stimulus"].unique().to_list()

print(f"Stimuli to process (from TRT): {len(stimuli_to_process)}")
print(f"Subjects: {trt['subject_id'].n_unique()}")
print(f"Conditions: {sorted(trt['condition'].unique().to_list())}")
# Out:
# Stimuli to process (from TRT): 152
# Subjects: 12
# Conditions: ['neg', 'pos', 'zero']

# %%
# Load AOI data for alignment
def load_aois(stimulus: str) -> pl.DataFrame | None:
    """Load AOI word-level data for a stimulus."""
    aoi_path = STIMULI_DIR / f"{stimulus}.word.csv"
    if not aoi_path.exists():
        return None
        
    aoi_df = pl.read_csv(aoi_path)
    required_cols = {"index", "content", "left", "right", "top", "bottom"}
    missing_cols = required_cols - set(aoi_df.columns)
    
    if missing_cols:
        raise ValueError(f"AOI file missing columns {missing_cols} for {stimulus}")
        
    return aoi_df.sort("index")  # Ensure consistent token order

# Load AOIs for all stimuli
stimulus_aois: dict[str, pl.DataFrame] = {}
missing_aois = []

for stimulus in stimuli_to_process:
    if is_practice(stimulus):
        continue
        
    aoi_df = load_aois(stimulus)
    if aoi_df is not None:
        stimulus_aois[stimulus] = aoi_df
    else:
        missing_aois.append(stimulus)

print(f"Loaded AOIs: {len(stimulus_aois)} stimuli")
if missing_aois:
    print(f"Missing AOI files: {missing_aois}")
# Out:
# Loaded AOIs: 152 stimuli

# %%
# Text loading with fallbacks
def load_text(stimulus: str, aoi_df: pl.DataFrame) -> str:
    """Load stimulus text from JSON, TXT, or reconstruct from AOIs."""
    # Try JSON first
    json_path = TEXTS_DIR / f"{stimulus}.json"
    if json_path.exists():
        try:
            data = json.loads(json_path.read_text(encoding="utf-8"))
            # Handle common JSON structures
            if isinstance(data, dict):
                for key in ("text", "content", "body"):
                    if key in data and isinstance(data[key], str) and data[key].strip():
                        return data[key]
                # Fallback: first string value
                for value in data.values():
                    if isinstance(value, str) and value.strip():
                        return value
        except (json.JSONDecodeError, UnicodeDecodeError):
            pass
    
    # Try TXT file
    txt_path = TEXTS_DIR / f"{stimulus}.txt" 
    if txt_path.exists():
        try:
            return txt_path.read_text(encoding="utf-8")
        except UnicodeDecodeError:
            pass
    
    # Fallback: reconstruct from AOI content
    return " ".join(aoi_df["content"].to_list())

# Test text loading for first few stimuli
for i, (stimulus, aoi_df) in enumerate(list(stimulus_aois.items())[:3]):
    text = load_text(stimulus, aoi_df)
    print(f"{stimulus}: {len(text)} chars, first 100: {text[:100]!r}")
    if i >= 2:  # Only show first 3
        break
# Out:
# breakfast-pos.text.1: 732 chars, first 100: 'bacon, and toast, Darla set down a plate piled high with pancakes, syrup-drenched and steaming. Conf'
# voicemail-neg.text.1: 630 chars, first 100: "Emily's heart began to pound in her chest as she listened to the message over and over, trying to ma"
# blackout-pos.question: 152 chars, first 100: 'What role does Mrs. Jenkins ultimately play in the story? A victim of the blackout A nosy neighbor A'

# %%
# Initialize spaCy pipeline
print("Loading spaCy model...")
nlp = spacy.load("en_core_web_sm", exclude=["ner"])  # Exclude NER for speed

# Ensure sentence segmentation
if not nlp.has_pipe("senter") and not nlp.has_pipe("parser"):
    nlp.add_pipe("sentencizer")

print(f"spaCy pipeline: {nlp.pipe_names}")

# Test parsing
test_text = "The quick brown fox jumps over the lazy dog."
doc = nlp(test_text)
print(f"Test parse: {len(doc)} tokens, {len(list(doc.sents))} sentences")
# Out:
# Loading spaCy model...
# spaCy pipeline: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer']
# Test parse: 10 tokens, 1 sentences

# %%
# Load SUBTLEX-US frequency data
from math import log10

def load_subtlex(path: Path) -> pl.DataFrame:
    """Load SUBTLEX data with robust column detection and scaling.
    Preference order:
    1) SUBTLWF (freq per million): Zipf = log10(SUBTLWF) + 3
    2) Any 'zipf' column: use as-is
    3) lg10WF: ONLY use as-is (no +3), because it's log10(raw frequency), not per million
       and adding +3 would inflate scales. This keeps it monotonic and comparable.
    """
    if not path.exists():
        raise FileNotFoundError(f"SUBTLEX file not found at {path}")

    df_raw = pl.read_csv(path, separator="\t", infer_schema_length=50000)
    cols_lc = {c.lower(): c for c in df_raw.columns}

    # word/form column
    word_col = None
    for candidate in ["word", "spelling", "lemma", "wordform"]:
        if candidate in cols_lc:
            word_col = cols_lc[candidate]
            break
    if not word_col:
        word_col = df_raw.columns[0]

    # 1) Prefer SUBTLWF if present (per million)
    subtlwf_col = None
    for k in ["subtlwf", "freqpm", "freq_per_million"]:
        if k in cols_lc:
            subtlwf_col = cols_lc[k]
            break

    if subtlwf_col:
        zipf_expr = (
            pl.when(pl.col(subtlwf_col).cast(pl.Float64) > 0)
            .then(pl.col(subtlwf_col).cast(pl.Float64).log10() + 3.0)
            .otherwise(None)
        )
    else:
        # 2) Any 'zipf' column
        zipf_candidates = [c for c in df_raw.columns if "zipf" in c.lower()]
        if zipf_candidates:
            base_col = zipf_candidates[0]
            zipf_expr = pl.col(base_col).cast(pl.Float64)
        else:
            # 3) lg10WF (log10 raw counts): use as-is to avoid artificial offset
            lg10_col = None
            for k in ["lg10wf", "log10wf", "lg10_wf"]:
                if k in cols_lc:
                    lg10_col = cols_lc[k]
                    break
            if lg10_col:
                zipf_expr = pl.col(lg10_col).cast(pl.Float64)
            else:
                raise ValueError("SUBTLEX file must have SUBTLWF, Zipf, or lg10WF column")

    result = (
        df_raw.select([
            pl.col(word_col).str.to_lowercase().alias("form"),
            zipf_expr.alias("zipf"),
        ])
        .filter(pl.col("form").str.len_chars() > 0)
        .filter(pl.col("zipf").is_not_null())
        .group_by("form").agg(pl.col("zipf").max())
    )
    return result

# Load SUBTLEX
print("Loading SUBTLEX-US...")
subtlex = load_subtlex(SUBTLEX_PATH)
print(f"SUBTLEX entries: {subtlex.height}")
print("Sample entries:")
print(subtlex.head().to_pandas())
# Out:
# Loading SUBTLEX-US...
# SUBTLEX entries: 74286
# Sample entries:
#            form      zipf
# 0         walsh  3.691965
# 1      buffeted  1.903090
# 2  permanganate  1.903090
# 3      counting  4.331832
# 4          pert  2.690196

# %%
# Dependency Locality Theory functions (Gibson 2000)

def token_depth(token) -> int:
    """Calculate syntactic tree depth: distance from token to root."""
    depth = 0
    current = token
    while current.head != current:  # Until we reach root
        depth += 1
        current = current.head
        if depth > 50:  # Prevent infinite loops
            break
    return depth

def dependency_distance(token) -> int:
    """Calculate linear dependency distance: |position - head_position|."""
    return abs(token.i - token.head.i)

def integration_cost(token) -> float:
    """
    Calculate integration cost based on Gibson 2000 Dependency Locality Theory.
    
    Integration cost reflects processing difficulty due to:
    1. Linear distance to syntactic head
    2. Number of discourse referents between dependent and head
    
    Simplified metric: linear distance weighted by dependency type.
    """
    if token.head == token:  # Root has no integration cost
        return 0.0
    
    dist = dependency_distance(token)
    
    # Weight by dependency relation importance (simplified)
    # More important relations have higher integration costs
    relation_weights = {
        "nsubj": 1.0,     # Subject
        "dobj": 1.0,      # Direct object  
        "prep": 0.8,      # Prepositional
        "amod": 0.6,      # Adjectival modifier
        "advmod": 0.6,    # Adverbial modifier
        "det": 0.3,       # Determiner
        "aux": 0.3,       # Auxiliary
        "punct": 0.1,     # Punctuation
    }
    
    weight = relation_weights.get(token.dep_, 0.5)  # Default weight
    
    # Integration cost = distance * relation_weight
    # Add small penalty for very long distances
    cost = dist * weight
    if dist > 5:
        cost += (dist - 5) * 0.1  # Additional penalty for long dependencies
        
    return cost

def locality_features(token) -> dict:
    """Extract all locality-related features for a token."""
    return {
        "dep_dist": dependency_distance(token),
        "depth": token_depth(token),
        "integration_cost": integration_cost(token),
        "dep_label": token.dep_,
        "pos_tag": token.pos_,
    }

# %%
# Frequency lookup function
def lookup_zipf(surface: str, lemma: str = "") -> float | None:
    """
    Look up Zipf frequency score.
    Try lemma first (more stable), then surface form.
    """
    # Normalize inputs
    surface_norm = normalize_token(surface.lower())
    lemma_norm = normalize_token(lemma.lower()) if lemma else ""
    
    # Try lemma first
    if lemma_norm:
        result = subtlex.filter(pl.col("form") == lemma_norm).select("zipf")
        if result.height > 0:
            return float(result.item())
    
    # Fallback to surface form
    if surface_norm:
        result = subtlex.filter(pl.col("form") == surface_norm).select("zipf")
        if result.height > 0:
            return float(result.item())
    
    return None  # Not found

# Test frequency lookup
test_words = ["the", "cat", "quickly", "xyzabc"]
for word in test_words:
    freq = lookup_zipf(word)
    print(f"{word}: {freq}")
# Out:
# the: 9.1766
# cat: 6.5294
# quickly: 6.4597
# xyzabc: None

# %%
# Main feature extraction
print("Extracting linguistic features...")

feature_tables = []
coverage_stats = []

for stimulus_idx, (stimulus, aoi_df) in enumerate(stimulus_aois.items()):
    print(f"Processing {stimulus_idx+1}/{len(stimulus_aois)}: {stimulus}")
    
    # Load and parse text
    text = load_text(stimulus, aoi_df)
    doc = nlp(text)
    
    # Get non-space tokens for alignment
    doc_tokens_all = [t for t in doc if not t.is_space]
    doc_tokens_text = [t.text for t in doc_tokens_all]
    
    # Get AOI tokens in order
    aoi_tokens = aoi_df.sort("index")["content"].to_list()
    aoi_indices = aoi_df.sort("index")["index"].to_list()
    
    # Align AOI tokens to spaCy tokens
    alignment = align_aoi_to_spacy(aoi_tokens, doc_tokens_text)
    
    # Calculate coverage
    aligned_count = sum(1 for x in alignment if x is not None)
    coverage = aligned_count / max(1, len(aoi_tokens))
    coverage_stats.append((stimulus, coverage, len(aoi_tokens), aligned_count))
    
    # Extract features for each AOI token
    rows = []
    for aoi_idx, content, spacy_idx in zip(aoi_indices, aoi_tokens, alignment):
        if spacy_idx is None:
            # Unaligned token - compute basic features only
            rows.append({
                "stimulus": stimulus,
                "index": int(aoi_idx),
                "content": content,
                "word_len": sum(c.isalpha() for c in content),
                "freq_zipf": None,
                "dep_dist": None,
                "depth": None,
                "integration_cost": None,
                "dep_label": None,
                "pos_tag": None,
                "lemma": None,
                "sentence_id": None,
                "token_id_sent": None,
            })
            continue
        
        # Get spaCy token
        token = doc_tokens_all[spacy_idx]
        
        # Calculate features
        word_len = sum(c.isalpha() for c in content)
        lemma = token.lemma_ if hasattr(token, 'lemma_') else ""
        freq_zipf = lookup_zipf(content, lemma)
        
        # Locality features  
        locality = locality_features(token)
        
        # Sentence information
        sentence_id = None
        token_id_sent = None
        for sent_idx, sent in enumerate(doc.sents):
            if token.i >= sent.start and token.i < sent.end:
                sentence_id = sent_idx
                token_id_sent = token.i - sent.start
                break
        
        rows.append({
            "stimulus": stimulus,
            "index": int(aoi_idx),
            "content": content,
            "word_len": word_len,
            "freq_zipf": freq_zipf,
            "dep_dist": locality["dep_dist"],
            "depth": locality["depth"], 
            "integration_cost": locality["integration_cost"],
            "dep_label": locality["dep_label"],
            "pos_tag": locality["pos_tag"],
            "lemma": lemma,
            "sentence_id": sentence_id,
            "token_id_sent": token_id_sent,
        })
    
    # Convert to DataFrame
    stimulus_features = pl.from_records(rows)
    feature_tables.append(stimulus_features)

print("Feature extraction complete.")
# Out:
# Extracting linguistic features...
# Processing 1/152: breakfast-pos.text.1
# Processing 2/152: voicemail-neg.text.1
# Processing 3/152: blackout-pos.question
# Processing 4/152: breakfast-zero.interest
# Processing 5/152: breakfast-neg.text.3
# Processing 6/152: breakfast-pos.interest
# Processing 7/152: goldfish-zero.text.1
# Processing 8/152: delayed-neg.question
# Processing 9/152: delayed-pos.question
# Processing 10/152: goldfish-zero.interest
# Processing 11/152: prize-pos.text.0
# Processing 12/152: goldfish-pos.question
# Processing 13/152: goldfish-neg.interest
# Processing 14/152: goldfish-pos.naturalness
# Processing 15/152: voicemail-pos.text.2
# Processing 16/152: blackout-neg.text.2
# Processing 17/152: delayed-zero.interest
# Processing 18/152: voicemail-pos.text.0
# Processing 19/152: prize-zero.text.2
# Processing 20/152: delayed-zero.text.0
# Processing 21/152: blackout-neg.difficulty
# Processing 22/152: delayed-pos.text.2
# Processing 23/152: goldfish-pos.text.0
# Processing 24/152: blackout-pos.text.4
# Processing 25/152: voicemail-zero.interest
# Processing 26/152: voicemail-zero.text.0
# Processing 27/152: goldfish-zero.naturalness
# Processing 28/152: breakfast-pos.text.2
# Processing 29/152: breakfast-zero.text.2
# Processing 30/152: prize-pos.question
# Processing 31/152: prize-neg.question
# Processing 32/152: goldfish-pos.text.4
# Processing 33/152: breakfast-zero.question
# Processing 34/152: voicemail-neg.text.0
# Processing 35/152: blackout-pos.difficulty
# Processing 36/152: delayed-neg.naturalness
# Processing 37/152: voicemail-pos.interest
# Processing 38/152: blackout-zero.interest
# Processing 39/152: prize-pos.interest
# Processing 40/152: blackout-pos.text.2
# Processing 41/152: goldfish-zero.difficulty
# Processing 42/152: prize-zero.naturalness
# Processing 43/152: prize-neg.text.1
# Processing 44/152: breakfast-neg.text.2
# Processing 45/152: voicemail-neg.naturalness
# Processing 46/152: voicemail-neg.text.2
# Processing 47/152: goldfish-zero.text.0
# Processing 48/152: blackout-zero.text.4
# Processing 49/152: voicemail-neg.question
# Processing 50/152: delayed-zero.text.1
# Processing 51/152: delayed-zero.naturalness
# Processing 52/152: delayed-pos.text.3
# Processing 53/152: delayed-neg.text.3
# Processing 54/152: breakfast-zero.text.3
# Processing 55/152: voicemail-pos.question
# Processing 56/152: goldfish-neg.question
# Processing 57/152: delayed-zero.text.3
# Processing 58/152: breakfast-pos.question
# Processing 59/152: breakfast-neg.interest
# Processing 60/152: breakfast-pos.difficulty
# Processing 61/152: blackout-zero.text.3
# Processing 62/152: voicemail-neg.difficulty
# Processing 63/152: blackout-pos.interest
# Processing 64/152: breakfast-neg.question
# Processing 65/152: prize-neg.interest
# Processing 66/152: delayed-neg.text.4
# Processing 67/152: goldfish-neg.text.3
# Processing 68/152: prize-neg.naturalness
# Processing 69/152: prize-neg.difficulty
# Processing 70/152: voicemail-pos.naturalness
# Processing 71/152: goldfish-pos.text.3
# Processing 72/152: blackout-pos.text.3
# Processing 73/152: voicemail-pos.text.1
# Processing 74/152: breakfast-zero.difficulty
# Processing 75/152: voicemail-zero.naturalness
# Processing 76/152: voicemail-neg.text.3
# Processing 77/152: voicemail-neg.interest
# Processing 78/152: blackout-pos.text.1
# Processing 79/152: breakfast-zero.text.0
# Processing 80/152: goldfish-pos.text.2
# Processing 81/152: goldfish-pos.interest
# Processing 82/152: prize-zero.question
# Processing 83/152: voicemail-zero.text.1
# Processing 84/152: goldfish-neg.text.2
# Processing 85/152: prize-zero.text.1
# Processing 86/152: prize-zero.text.0
# Processing 87/152: voicemail-zero.text.2
# Processing 88/152: goldfish-zero.text.3
# Processing 89/152: prize-pos.difficulty
# Processing 90/152: goldfish-pos.text.1
# Processing 91/152: prize-pos.text.3
# Processing 92/152: delayed-pos.interest
# Processing 93/152: prize-neg.text.2
# Processing 94/152: blackout-zero.text.0
# Processing 95/152: blackout-neg.question
# Processing 96/152: delayed-pos.naturalness
# Processing 97/152: voicemail-zero.difficulty
# Processing 98/152: prize-zero.text.3
# Processing 99/152: goldfish-neg.difficulty
# Processing 100/152: blackout-zero.question
# Processing 101/152: goldfish-zero.question
# Processing 102/152: voicemail-zero.question
# Processing 103/152: voicemail-zero.text.3
# Processing 104/152: prize-pos.naturalness
# Processing 105/152: prize-pos.text.4
# Processing 106/152: breakfast-zero.naturalness
# Processing 107/152: breakfast-pos.text.0
# Processing 108/152: breakfast-zero.text.1
# Processing 109/152: delayed-pos.text.1
# Processing 110/152: prize-pos.text.2
# Processing 111/152: breakfast-pos.text.3
# Processing 112/152: goldfish-neg.text.1
# Processing 113/152: goldfish-zero.text.2
# Processing 114/152: blackout-neg.text.0
# Processing 115/152: prize-zero.difficulty
# Processing 116/152: delayed-neg.text.1
# Processing 117/152: goldfish-neg.naturalness
# Processing 118/152: prize-zero.text.4
# Processing 119/152: delayed-neg.text.2
# Processing 120/152: delayed-neg.difficulty
# Processing 121/152: voicemail-pos.text.3
# Processing 122/152: prize-zero.interest
# Processing 123/152: delayed-zero.text.4
# Processing 124/152: delayed-pos.text.0
# Processing 125/152: delayed-pos.difficulty
# Processing 126/152: prize-neg.text.3
# Processing 127/152: delayed-zero.question
# Processing 128/152: blackout-zero.text.2
# Processing 129/152: blackout-neg.text.1
# Processing 130/152: delayed-neg.interest
# Processing 131/152: blackout-neg.interest
# Processing 132/152: delayed-zero.text.2
# Processing 133/152: voicemail-pos.difficulty
# Processing 134/152: breakfast-pos.naturalness
# Processing 135/152: breakfast-neg.text.1
# Processing 136/152: blackout-zero.text.1
# Processing 137/152: blackout-pos.text.0
# Processing 138/152: blackout-zero.difficulty
# Processing 139/152: blackout-neg.naturalness
# Processing 140/152: prize-pos.text.1
# Processing 141/152: goldfish-neg.text.0
# Processing 142/152: breakfast-neg.difficulty
# Processing 143/152: breakfast-neg.naturalness
# Processing 144/152: blackout-zero.naturalness
# Processing 145/152: blackout-pos.naturalness
# Processing 146/152: delayed-zero.difficulty
# Processing 147/152: prize-neg.text.0
# Processing 148/152: goldfish-zero.text.4
# Processing 149/152: delayed-neg.text.0
# Processing 150/152: breakfast-neg.text.0
# Processing 151/152: goldfish-pos.difficulty
# Processing 152/152: blackout-neg.text.3
# Feature extraction complete.

# %%
# Consolidate all features
features = pl.concat(feature_tables, how="vertical_relaxed")

# Cast to appropriate types
features = features.with_columns([
    pl.col("stimulus").cast(pl.Utf8),
    pl.col("index").cast(pl.Int64),  # Match TRT data type
    pl.col("content").cast(pl.Utf8),
    pl.col("word_len").cast(pl.Int16),
    pl.col("freq_zipf").cast(pl.Float64),
    pl.col("dep_dist").cast(pl.Int16),
    pl.col("depth").cast(pl.Int16),
    pl.col("integration_cost").cast(pl.Float64),
    pl.col("dep_label").cast(pl.Utf8),
    pl.col("pos_tag").cast(pl.Utf8),
    pl.col("lemma").cast(pl.Utf8),
    pl.col("sentence_id").cast(pl.Int32),
    pl.col("token_id_sent").cast(pl.Int32),
])

# Save features
FEATURES_PARQUET = PROC / "features_by_word.parquet"
FEATURES_CSV = PROC / "features_by_word.csv"

features.write_parquet(FEATURES_PARQUET)
features.write_csv(FEATURES_CSV)

print(f"Saved features: {features.height} rows -> {FEATURES_PARQUET}")
print(f"Columns: {features.columns}")
# Out:
# Saved features: 9905 rows -> data-clean\processed\features_by_word.parquet
# Columns: ['stimulus', 'index', 'content', 'word_len', 'freq_zipf', 'dep_dist', 'depth', 'integration_cost', 'dep_label', 'pos_tag', 'lemma', 'sentence_id', 'token_id_sent']

# %%
# Merge with TRT data for modeling
print("Merging features with TRT data...")

trt_with_features = trt.join(
    features, 
    on=["stimulus", "index", "content"], 
    how="left"
)

# Save merged data
TRT_FEATURES_PARQUET = PROC / "trt_with_features.parquet"
TRT_FEATURES_CSV = PROC / "trt_with_features.csv"

trt_with_features.write_parquet(TRT_FEATURES_PARQUET)
trt_with_features.write_csv(TRT_FEATURES_CSV)

print(f"Saved merged data: {trt_with_features.height} rows -> {TRT_FEATURES_PARQUET}")

# Basic statistics
null_counts = trt_with_features.null_count()
print("\nNull counts in merged data:")
for col in ["freq_zipf", "dep_dist", "depth", "integration_cost"]:
    nulls = null_counts.select(pl.col(col)).item()
    total = trt_with_features.height
    print(f"{col}: {nulls}/{total} ({nulls/total*100:.1f}%)")

print(f"\nFinal columns: {trt_with_features.columns}")
# Out:
# Merging features with TRT data...
# Saved merged data: 36160 rows -> data-clean\processed\trt_with_features.parquet
#
# Null counts in merged data:
# freq_zipf: 19832/36160 (54.8%)
# dep_dist: 18922/36160 (52.3%)
# depth: 18922/36160 (52.3%)
# integration_cost: 18922/36160 (52.3%)
#
# Final columns: ['subject_id', 'stimulus', 'condition', 'index', 'content', 'total_reading_time', 'word_len', 'freq_zipf', 'dep_dist', 'depth', 'integration_cost', 'dep_label', 'pos_tag', 'lemma', 'sentence_id', 'token_id_sent']

# %%
# Coverage and validation report
print("\n=== ALIGNMENT COVERAGE REPORT ===")
good_coverage = sum(1 for _, cov, _, _ in coverage_stats if cov >= 0.9)
print(f"Stimuli with ≥90% token alignment: {good_coverage}/{len(coverage_stats)}")

print("\nPer-stimulus coverage:")
for stimulus, coverage, total_tokens, aligned_tokens in sorted(coverage_stats, key=lambda x: x[1]):
    print(f"{stimulus}: {coverage:.1%} ({aligned_tokens}/{total_tokens})")

print("\n=== FEATURE SUMMARY ===")
feature_summary = features.select([
    pl.col("word_len").mean().alias("avg_word_len"),
    pl.col("freq_zipf").mean().alias("avg_freq_zipf"),
    pl.col("dep_dist").mean().alias("avg_dep_dist"),
    pl.col("depth").mean().alias("avg_depth"),
    pl.col("integration_cost").mean().alias("avg_integration_cost"),
]).to_pandas().iloc[0]

for col, val in feature_summary.items():
    print(f"{col}: {val:.2f}")

print("\n=== DEPENDENCY RELATIONS ===")
dep_counts = features.group_by("dep_label").len().sort("len", descending=True).head(10)
print(dep_counts.to_pandas())

print("\nPipeline completed successfully!")
print(f"Ready for mixed-effects modeling with {trt_with_features.height} observations")
print(f"Subjects: {trt_with_features['subject_id'].n_unique()}")
print(f"Conditions: {sorted(trt_with_features['condition'].unique().to_list())}")
# Out:
# === ALIGNMENT COVERAGE REPORT ===
# Stimuli with ≥90% token alignment: 28/152
#
# Per-stimulus coverage:
# voicemail-neg.text.1: 0.0% (0/120)
# goldfish-pos.text.2: 0.0% (0/69)
# goldfish-neg.text.2: 0.0% (0/125)
# goldfish-pos.text.1: 0.0% (0/87)
# blackout-pos.text.3: 1.0% (1/100)
# prize-pos.text.3: 1.2% (1/82)
# prize-zero.text.4: 1.4% (1/74)
# breakfast-neg.text.2: 1.6% (2/129)
# goldfish-zero.text.0: 2.7% (3/113)
# breakfast-zero.text.2: 3.1% (3/98)
# breakfast-pos.text.2: 3.1% (3/97)
# prize-zero.text.3: 3.3% (3/90)
# blackout-pos.text.1: 4.6% (4/87)
# delayed-pos.text.1: 5.3% (5/95)
# prize-pos.text.2: 5.3% (4/75)
# voicemail-neg.text.2: 5.4% (6/112)
# delayed-zero.text.2: 5.4% (6/112)
# voicemail-pos.text.2: 5.6% (5/90)
# breakfast-pos.text.0: 5.7% (5/87)
# delayed-zero.text.0: 7.4% (8/108)
# delayed-pos.text.3: 7.5% (3/40)
# voicemail-zero.text.2: 7.6% (9/118)
# voicemail-neg.text.0: 8.9% (9/101)
# voicemail-zero.text.0: 9.5% (9/95)
# goldfish-zero.text.3: 9.5% (12/126)
# breakfast-pos.text.1: 10.4% (12/115)
# goldfish-pos.text.0: 10.8% (7/65)
# goldfish-pos.text.4: 11.5% (9/78)
# prize-pos.text.0: 12.5% (11/88)
# breakfast-pos.question: 12.5% (4/32)
# prize-neg.text.0: 13.2% (16/121)
# breakfast-zero.text.1: 13.6% (12/88)
# breakfast-neg.text.0: 14.2% (15/106)
# prize-zero.text.0: 14.4% (16/111)
# blackout-pos.text.2: 14.6% (12/82)
# delayed-pos.text.0: 15.5% (11/71)
# delayed-zero.text.3: 16.2% (13/80)
# breakfast-pos.text.3: 16.5% (14/85)
# blackout-neg.text.3: 17.1% (19/111)
# goldfish-neg.text.3: 17.4% (24/138)
# delayed-pos.text.2: 18.0% (16/89)
# voicemail-pos.text.0: 18.1% (17/94)
# voicemail-zero.text.3: 19.2% (10/52)
# goldfish-zero.text.1: 21.8% (24/110)
# delayed-neg.text.3: 23.0% (31/135)
# voicemail-pos.text.3: 29.9% (20/67)
# delayed-zero.text.4: 30.6% (33/108)
# delayed-zero.text.1: 32.5% (26/80)
# goldfish-pos.text.3: 32.5% (26/80)
# prize-zero.text.2: 35.7% (40/112)
# breakfast-zero.text.3: 37.9% (33/87)
# prize-zero.question: 39.3% (11/28)
# voicemail-pos.text.1: 40.4% (36/89)
# delayed-neg.text.0: 45.4% (49/108)
# delayed-neg.text.1: 49.5% (52/105)
# delayed-neg.text.4: 50.0% (50/100)
# blackout-neg.question: 50.0% (15/30)
# voicemail-zero.text.1: 55.7% (54/97)
# goldfish-neg.question: 60.5% (26/43)
# prize-neg.text.2: 63.4% (92/145)
# goldfish-neg.text.0: 66.1% (76/115)
# goldfish-zero.text.2: 71.0% (110/155)
# voicemail-neg.text.3: 71.1% (59/83)
# prize-zero.text.1: 71.8% (84/117)
# goldfish-neg.text.1: 72.8% (99/136)
# delayed-neg.text.2: 74.8% (83/111)
# blackout-zero.text.2: 79.7% (98/123)
# breakfast-zero.interest: 82.6% (19/23)
# breakfast-pos.interest: 82.6% (19/23)
# goldfish-zero.interest: 82.6% (19/23)
# goldfish-neg.interest: 82.6% (19/23)
# delayed-zero.interest: 82.6% (19/23)
# voicemail-zero.interest: 82.6% (19/23)
# voicemail-pos.interest: 82.6% (19/23)
# blackout-zero.interest: 82.6% (19/23)
# prize-pos.interest: 82.6% (19/23)
# breakfast-neg.interest: 82.6% (19/23)
# blackout-pos.interest: 82.6% (19/23)
# prize-neg.interest: 82.6% (19/23)
# voicemail-neg.interest: 82.6% (19/23)
# goldfish-pos.interest: 82.6% (19/23)
# delayed-pos.interest: 82.6% (19/23)
# prize-zero.interest: 82.6% (19/23)
# delayed-neg.interest: 82.6% (19/23)
# blackout-neg.interest: 82.6% (19/23)
# breakfast-zero.text.0: 84.3% (86/102)
# goldfish-pos.naturalness: 85.2% (23/27)
# blackout-neg.difficulty: 85.2% (23/27)
# goldfish-zero.naturalness: 85.2% (23/27)
# blackout-pos.difficulty: 85.2% (23/27)
# delayed-neg.naturalness: 85.2% (23/27)
# goldfish-zero.difficulty: 85.2% (23/27)
# prize-zero.naturalness: 85.2% (23/27)
# voicemail-neg.naturalness: 85.2% (23/27)
# delayed-zero.naturalness: 85.2% (23/27)
# breakfast-pos.difficulty: 85.2% (23/27)
# voicemail-neg.difficulty: 85.2% (23/27)
# prize-neg.naturalness: 85.2% (23/27)
# prize-neg.difficulty: 85.2% (23/27)
# voicemail-pos.naturalness: 85.2% (23/27)
# breakfast-zero.difficulty: 85.2% (23/27)
# voicemail-zero.naturalness: 85.2% (23/27)
# prize-pos.difficulty: 85.2% (23/27)
# delayed-pos.naturalness: 85.2% (23/27)
# voicemail-zero.difficulty: 85.2% (23/27)
# goldfish-neg.difficulty: 85.2% (23/27)
# prize-pos.naturalness: 85.2% (23/27)
# breakfast-zero.naturalness: 85.2% (23/27)
# prize-zero.difficulty: 85.2% (23/27)
# goldfish-neg.naturalness: 85.2% (23/27)
# delayed-neg.difficulty: 85.2% (23/27)
# delayed-pos.difficulty: 85.2% (23/27)
# voicemail-pos.difficulty: 85.2% (23/27)
# breakfast-pos.naturalness: 85.2% (23/27)
# blackout-zero.difficulty: 85.2% (23/27)
# blackout-neg.naturalness: 85.2% (23/27)
# breakfast-neg.difficulty: 85.2% (23/27)
# breakfast-neg.naturalness: 85.2% (23/27)
# blackout-zero.naturalness: 85.2% (23/27)
# blackout-pos.naturalness: 85.2% (23/27)
# delayed-zero.difficulty: 85.2% (23/27)
# goldfish-pos.difficulty: 85.2% (23/27)
# blackout-pos.text.0: 88.0% (81/92)
# blackout-neg.text.2: 88.4% (99/112)
# prize-pos.text.4: 93.9% (31/33)
# breakfast-neg.text.3: 96.7% (87/90)
# goldfish-zero.text.4: 98.1% (52/53)
# blackout-neg.text.1: 99.2% (126/127)
# blackout-pos.question: 100.0% (26/26)
# delayed-neg.question: 100.0% (31/31)
# delayed-pos.question: 100.0% (35/35)
# goldfish-pos.question: 100.0% (30/30)
# blackout-pos.text.4: 100.0% (23/23)
# prize-pos.question: 100.0% (27/27)
# prize-neg.question: 100.0% (32/32)
# breakfast-zero.question: 100.0% (25/25)
# prize-neg.text.1: 100.0% (147/147)
# blackout-zero.text.4: 100.0% (66/66)
# voicemail-neg.question: 100.0% (41/41)
# voicemail-pos.question: 100.0% (32/32)
# blackout-zero.text.3: 100.0% (123/123)
# breakfast-neg.question: 100.0% (35/35)
# blackout-zero.text.0: 100.0% (113/113)
# blackout-zero.question: 100.0% (32/32)
# goldfish-zero.question: 100.0% (33/33)
# voicemail-zero.question: 100.0% (31/31)
# blackout-neg.text.0: 100.0% (113/113)
# prize-neg.text.3: 100.0% (136/136)
# delayed-zero.question: 100.0% (34/34)
# breakfast-neg.text.1: 100.0% (150/150)
# blackout-zero.text.1: 100.0% (89/89)
# prize-pos.text.1: 100.0% (106/106)
#
# === FEATURE SUMMARY ===
# avg_word_len: 4.31
# avg_freq_zipf: 7.55
# avg_dep_dist: 2.14
# avg_depth: 2.24
# avg_integration_cost: 1.27
#
# === DEPENDENCY RELATIONS ===
#   dep_label   len
# 0      None  5096
# 1       det   521
# 2     nsubj   490
# 3    advmod   417
# 4      prep   393
# 5      ROOT   388
# 6      amod   383
# 7      pobj   373
# 8      dobj   203
# 9       aux   189
#
# Pipeline completed successfully!
# Ready for mixed-effects modeling with 36160 observations
# Subjects: 12
# Conditions: ['neg', 'pos', 'zero']
